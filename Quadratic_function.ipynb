# %%
import pandas as pd
import numpy as np

# %%
numbers = []
for i in range(0,1000):
    numbers.append(i+1)

# %%
numbers_df = pd.DataFrame(numbers, columns=['x'])

# %%
numbers_df['y_sqrt'] = np.sqrt(numbers_df['x'])
numbers_df['y_linear'] = numbers_df['x']

# %%
numbers_df[0:10].plot()
# Out:
# <AxesSubplot: >

# %%
numbers_df[0:100].plot()
# Out:
# <AxesSubplot: >

# %%
numbers_df[0:1000].plot()
# Out:
# <AxesSubplot: >
